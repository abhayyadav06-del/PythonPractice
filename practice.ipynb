# %%
fruits = ["apple","mango"]
x, y= fruits

print(x)
print(y)
# Out:
# apple
# mango

# %%
x = "Machine Learning"

def myfunc():
    x ="Deep learning"
    print("Python is" +x)
myfunc()

print("Python is" +x)
# Out:
# Python isDeep learning
# Python isMachine Learning

# %%
x = "python"
x = 10
print(x)
# Out:
# 10

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
#python typecasting
x = int(1)

y = int(10.20)

z = int("3")

print(x)

print(y)

print(z)
# Out:
# 1
# 10
# 3

# %%
x = str("11")

y = str(2)

z = str(3.0)


print(x)

print(y)

print(z)
# Out:
# 11
# 2
# 3.0

# %%
x = ("Machine learning is a subset of Artificial Intelligence (AI) where computers learn from data and identify patterns without being explicitly programmed. Instead of following hard-coded rules, an algorithm uses past examples to adapt, make decisions, and improve its accuracy over time")

print(x)
# Out:
# Machine learning is a subset of Artificial Intelligence (AI) where computers learn from data and identify patterns without being explicitly programmed. Instead of following hard-coded rules, an algorithm uses past examples to adapt, make decisions, and improve its accuracy over time

# %%
#python - Slicing Strings
#Slicing Syntax
#syntax: variable(start:stop:step)

x = "Hello, world"
print(x[2:5])
# Out:
# llo

# %%
a = "Hello, world"
print(a.upper())
print(a.lower())
# Out:
# HELLO, WORLD
# hello, world

# %%
x = 10
x += 5
print(x)
# Out:
# 15

# %%
x = 25
x %= 7
print(x)
# Out:
# 4

# %%
a = 6
a **= 2
a += 4
print(a)
# Out:
# 40

# %%
balance = 10000
balance += 5000
balance -= 3000
balance *= 2
print(balance)
# Out:
# 24000

# %%
x = 20
y = 7
x += y
y += x
print(x,y)
# Out:
# 27 34

# %%
a = 20
a -= 10
a *= 3
a //= 4
print(a)
# Out:
# 7

# %%
#Comparison operator ==, !=, >, <,>=, <=

a = 20
b = 20
print(a == b)
# Out:
# True

# %%
temp = 30
print(temp < 35)
# Out:
# True

# %%
x = 20
y = 15
print(x > y)
print(x < y)
print(x == y)
# Out:
# True
# False
# False

# %%
#Logical operator in python and, or, not
age = 20
has_license = True
print(age >= 18 and has_license)
# Out:
# True

# %%
marks = 35
sport = True
print(marks >= 50 and sport ==true)
# Out:
# False

# %%
#Identity operator in python is, is not
a = [1,2,3]
b = [1,6,3]
print(a is not b)
print(a is b)
# Out:
# True
# False

# %%
#Membership operator in python: in, not in
fruits = ["apple", "mango", "grapes"]
print("Banana" in fruits)
# Out:
# False

# %%
#Bitwise operator in python: &, |, ^, -, <<, >>
a = 10
b = 6
print(a & b)
# Out:
# 2

# %%
#Left Shifft
a = 5
print( a << 1)
print( a << 2)
# Out:
# 10
# 20

# %%
#Right Shift
a = 5
print( a >> 1)
print( a >> 2)
# Out:
# 2
# 1
